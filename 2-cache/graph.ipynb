# %%
import matplotlib.pyplot as plt

block_sizes = [4, 8, 16, 32]
miss_rate_4kb = [0.165, 0.174, 0.161, 0.156]
miss_rate_8kb = [0.112, 0.117, 0.108, 0.103]
miss_rate_16kb = [0.075, 0.077, 0.070, 0.066]
miss_rate_32kb = [0.052, 0.052, 0.047, 0.044]

plt.plot(block_sizes, miss_rate_4kb, marker='o', label='4 KB Cache')
plt.plot(block_sizes, miss_rate_8kb, marker='o', label='8 KB Cache')
plt.plot(block_sizes, miss_rate_16kb, marker='o', label='16 KB Cache')
plt.plot(block_sizes, miss_rate_32kb, marker='o', label='32 KB Cache')

plt.title("Direct Mapped (gcc_Id_trace.txt)")
plt.xlabel("Block Size (Bytes)")
plt.ylabel("Miss Rate")
plt.legend(title="Cache Size", bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.)
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

cache_sizes = [1, 4, 8, 32, 512, 1024]
two_way_lru = [0.254, 0.120, 0.083, 0.030, 0.013, 0.013]
two_way_rr = [0.271, 0.130, 0.089, 0.033, 0.013, 0.013]
four_way_lru = [0.236, 0.107, 0.074, 0.025, 0.013, 0.013]
four_way_rr = [0.262, 0.120, 0.083, 0.028, 0.013, 0.013]

plt.plot(cache_sizes, two_way_lru, marker='o', label='Two-way LRU Cache')
plt.plot(cache_sizes, two_way_rr, marker='o', label='Two-way RR Cache')
plt.plot(cache_sizes, four_way_lru, marker='o', label='Four-way LRU Cache')
plt.plot(cache_sizes, four_way_rr, marker='o', label='Four-way RR Cache')

plt.title("N-Way Associative (block size = 4 bytes) (gcc_Id_trace.txt)")
plt.xlabel("Cache Size (KB)")
plt.ylabel("Miss Rate")
plt.grid(True)
plt.legend(title="Cache")
plt.xscale('log')

plt.show()
